# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv('KK52-14B563-ZD.csv')

# %%
data.head()
# Out:
#   AAdil Chatatou                 AChatatou@lear.com            060318
# 0  B5TX79P0BD         P KK52-14B563-ZC           ...
# 1  C5TX79P0BD         163300023                  ...
# 2  C5TX79P0BD         163300049                  ...
# 3  C5TX79P0BD         163300056                  ...
# 4  C5TX79P0BD         163303043                  ...

# %%
data.shape
# Out:
# (73, 1)

# %%
tmp = data.columns

# %%
data.columns = ['column1']

# %%
data['column1'][1]
# Out:
# 'C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     '

# %%
data['column1'][1]
# Out:
# 'C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     '

# %%
import re

def is_word_in_text(word, text):
    """
    Check if a word is in a text.

    Parameters
    ----------
    word : str
    text : str

    Returns
    -------
    bool : True if word is in text, otherwise False.

    Examples
    --------
    >>> is_word_in_text("Python", "python is awesome.")
    True

    >>> is_word_in_text("Python", "camelCase is pythonic.")
    False

    >>> is_word_in_text("Python", "At the end is Python")
    True
    """
    pattern = r'(^|[^\w]){}([^\w]|$)'.format(word)
    pattern = re.compile(pattern)
    matches = re.search(pattern, text)
    return bool(matches)

# %%
X =is_word_in_text('99999ITEM',data['column1'][1])

# %%
Y=is_word_in_text('WIRE',data['column1'][1])

# %%
def containAllWord(text, words):
    for oneWord in words:
        if oneWord not in text:
            return False
    return True
 
def containAtLeastOneWord(text, words):
    for oneWord in words:
        if oneWord in text:
            return True
    return False
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", "Wire"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', 'Wire'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', 'Wire'] )
# 	===> True
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', 'Wire'] )
# 	===> True
# containAllWord( C5TX79P0BD         163300056                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 01.00 YE                   163300056                     , ['99999ITEM', 'Wire'] )
# ...

# %%
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", "Terminal"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', 'Terminal'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', 'Terminal'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', 'Terminal'] )
# 	===> False
# ...

# %%
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", " Clip"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', ' Clip'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', ' Clip'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', ' Clip'] )
# 	===> False
# ...

# %%
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", " Connector"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', ' Connector'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', ' Connector'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', ' Connector'] )
# 	===> False
# ...

# %%
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", " Tape"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', ' Tape'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', ' Tape'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', ' Tape'] )
# 	===> False
# ...

# %%
for i in range(73):
    if __name__ == '__main__':
        tests = [
              ( data['column1'][i], ["99999ITEM", " Tube"] )
           ]
 
    for oneTest in tests:
        
 
        for oneFunction in [containAllWord]:
            print (oneFunction.__name__ + '( ' + oneTest[0] + ', ' + str(oneTest[1]) +' )')
            print ('\t===> ' + str( oneFunction(oneTest[0], oneTest[1]) ))
# Out:
# containAllWord( B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG                            , ['99999ITEM', ' Tube'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     , ['99999ITEM', ' Tube'] )
# 	===> False
# containAllWord( C5TX79P0BD         163300049                  1.4200000000M     99999ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049                     , ['99999ITEM', ' Tube'] )
# 	===> False
# ...

# %%
def containAllWord(text, words):
    for oneWord in words:
        if oneWord not in text:
            return False
    return True

# %%
data['column1'][1]
# Out:
# 'C5TX79P0BD         163300023                  0.6550000000M     99999ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     '

# %%
data['column1'][1].replace('99999ITEM','50ITEM')
# Out:
# 'C5TX79P0BD         163300023                  0.6550000000M     50ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023                     '

# %%
z=containAllWord(data['column1'][5],['99999ITEM', ' Wire'])

# %%
if(z):
    data['column1'][5] =data['column1'][5].replace('99999ITEM','50ITEM')

# %%
data['column1'][5]
# Out:
# 'C5TX79P0BD         163304017                  0.9650000000M     50ITEM                      Wire                WIRE WA T105 00.35 BN                   163304017                     '

# %%
for i in range(73):
    if (containAllWord(data['column1'][i],['99999ITEM', ' Wire'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','5ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', ' Terminal'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','5ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', 'Connector '])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','30ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', 'Clip'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','30ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', 'Tape'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','30ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', 'Other'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','30ITEM')
    if (containAllWord(data['column1'][i],['99999ITEM', 'Tube'])):
            data['column1'][i] =data['column1'][i].replace('99999ITEM','30ITEM')

# %%
for i in range(73):
    print(data['column1'][i])
# Out:
# B5TX79P0BD         P KK52-14B563-ZC                H-OTHERSN/A     PP19_A5+ECR208673CPP19_A4+ECR20782KK52-14B563-BD                MA02JL06LR05 0.000ZZZZZZZZZZZZ        JAGUAR CARS LIMITED           JG
# C5TX79P0BD         163300023                  0.6550000000M     5ITEM                      Wire                WIRE WA T105 00.50 YE                   163300023
# C5TX79P0BD         163300049                  1.4200000000M     5ITEM                      Wire                WIRE WA T105 00.75 YE                   163300049
# C5TX79P0BD         163300056                  1.4200000000M     5ITEM                      Wire                WIRE WA T105 01.00 YE                   163300056
# C5TX79P0BD         163303043                  1.4200000000M     5ITEM                      Wire                WIRE WA T105 00.75 GY                   163303043
# ...

# %%
data.columns = tmp

# %%
data.to_csv('out.csv')
